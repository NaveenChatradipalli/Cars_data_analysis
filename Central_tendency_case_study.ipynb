# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveenChatradipalli/Cars_data_analysis/blob/main/Central_tendency_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load "Numpy" and "Pandas" for manipulating data frames
# Load "Matplotlib.pyplot" and "Seaborn" for data visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Wine Quality Dataset.csv')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %% [markdown]
# # Task - 1: Load and study the data
#
# Load the data and study its features such as:
#  * fixed acidity
#  * volatile acidity
#  * citric acid etc.

# %%
# Get the dimensions of the dataframe
data.shape
# Out:
# (4898, 12)

# %%
# Get the parameters of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=4898, step=1)

# %%
# Get the column names of the dataframe
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Look at the basic info of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# # Observation of the Task 1
#
# There are 4898 rows and 12 columns in the data. Each row contains the details of the types of acids present in white-wine and the quality
#
# The features in the data set are:
# * Different acids and their quality
#
# # Task 2- View the distributions of the various features in the dataset and their central tendencies
#
# We look now at the distributions of the various features in the data set
#
# We will also calculate appropriate measures of central tendency for these features

# %%
# Create a histogram of the "Fixed acidity" feature

plt.figure(figsize=(11, 6))

sns.histplot(data = data, x = 'fixed acidity', color = 'orange',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Fixed Acidity")
plt.xlabel("Fixed Acidity")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Observations
#
# We observe that the histogram is normally distributed.
#
# The maximum count of the values for fixed acidity lies in between 6 to 8.
#
# Let's see the measures of central tendency in working!
#
# 1. Mean
# 2. Median
# 3. Mode

# %%
# Calculate the mean for "fixed acidity" feature
round(data['fixed acidity'].mean(), 2)
# Out:
# np.float64(6.85)

# %%
# Calculate the median for "fixed acidity" feature
data['fixed acidity'].median()
# Out:
# 6.8

# %%
# Create a histogram of the "Fixed acidity" feature and also show the mean and median
plt.figure(figsize=(11, 6))

sns.histplot(data = data, x = 'fixed acidity', color = 'orange',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Fixed Acidity")
plt.xlabel("Fixed Acidity")
plt.ylabel("Count")
plt.vlines(data['fixed acidity'].mean(), ymin = 0, ymax = 4000, colors = 'blue', label = "Mean")
plt.vlines(data['fixed acidity'].median(), ymin = 0, ymax = 4000, colors = 'red', label = "Median")
plt.legend()
plt.show()

# %% [markdown]
# # Observations
# We can see that mean and median are clear representative of the data.
#
# Mean and Median are very close to each other.
#
# We can choose either of the parameters say mean as the measure of the central tendency.

# %%
# Create a histogram of the "volatile acidity" feature

plt.figure(figsize=(11, 6))

sns.histplot(data = data, x = 'volatile acidity', color = 'green',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Volatile Acidity")
plt.xlabel("Volatile Acidity")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Observations
# We observe that the histogram is not well distributed, it is skewed a little towards the right.
#
# As we have seen skewness, therefore we can check the distribution using displot function.
#
# * If Skewness(S) > 0, then the distribution is positively skewed.
# * If Skewness(S) < 0, then the distribution is negatively skewed.
# * If Skewness(S) = 0, then the distribution is normally distributed.

# %%
# Plot displot using 'Volatile acidity'
plt.figure(figsize=(11, 6))

sns.distplot(data['volatile acidity'], color = 'blue')

plt.title("Displot of Volatile Acidity")
plt.xlabel("Volatile Acidity")
plt.ylabel("Density")
plt.show()
# Out:
# /tmp/ipykernel_689/1169755670.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['volatile acidity'], color = 'blue')

# %% [markdown]
# # Observation
#
# The above plot shows the normal distribution.
#
# The normal distribution is often described by the mean and the standard deviation.
#
# The normal distribution is often refered to as a "bell curve" because of it's shape:
# * The median and mean are equal
# * It has only one mode
# * It is symmetric, meaning it decreases the same amount on the left and the right of the centre.
#
# We can also calculate the skewness too using skew() function in Python.

# %%
# Calculate skewness of 'Volatile Acidity'
data['volatile acidity'].skew()
# Out:
# np.float64(1.5769795029952025)

# %% [markdown]
# # Observation
# We can clearly see that the skewness value is greater than 1 hence it is positively skewed.

# %%
# Calculate the mean "Volatile acidity" feature
data["volatile acidity"].mean()
# Out:
# np.float64(0.27824111882400976)

# %%
# Calculate the median "Volatile acidity" feature
data["volatile acidity"].median()
# Out:
# 0.26

# %%
# Create a histogram of the "Volatile acidity" feature and also show the mean and median
plt.figure(figsize=(11, 6))

sns.histplot(data = data, x = 'volatile acidity', color = 'green',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Volatile Acidity")
plt.xlabel("Volatile Acidity")
plt.ylabel("Density")
plt.vlines(data['volatile acidity'].mean(), ymin = 0, ymax = 4000, colors = 'blue', label = "Mean")
plt.vlines(data['volatile acidity'].median(), ymin = 0, ymax = 4000, colors = 'red', label = "Median")
plt.legend()
plt.show()

# %% [markdown]
# # Observation
# The mean and median are close to each other and the differences between them is very small.
#
# We can safely choose the mean as the measures of the central tendency here.

# %%
# create a histogram of the "critic acid" feature
plt.figure(figsize=(11, 6))

sns.histplot(data = data, x = 'citric acid', color = 'red',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Citric Acidity")
plt.xlabel("Citric Acidity")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Observation
# We observe that this histogram is not well distributed, it is skewed a little towards the right.

# %%
# Calculate the mean "Citric acid" feature
data["citric acid"].mean()
# Out:
# np.float64(0.33419150673744386)

# %%
# Calculate the median "Citric acid" feature
data["citric acid"].median()
# Out:
# 0.32

# %%
# Create a histogram of the "citric acid" feature and also show the mean and median
plt.figure(figsize=(11, 6))

sns.histplot(data = data, x = 'citric acid', color = 'red',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Citric Acidity")
plt.xlabel("Citric Acidity")
plt.ylabel("Count")
plt.vlines(data['citric acid'].mean(), ymin = 0, ymax = 4000, colors = 'blue', label = "Mean")
plt.vlines(data['citric acid'].median(), ymin = 0, ymax = 4000, colors = 'red', label = "Median")
plt.legend()
plt.show()

# %% [markdown]
# # Observation
# The mean and median are close to each other and the differences between them is very small.
#
# We can safely choose the mean as the measures of the central tendency here.

# %%
# Plot displot using 'Citric acidity'
plt.figure(figsize=(11, 6))

sns.distplot(data['citric acid'], color = 'blue')

plt.title("Displot of Citric Acid")
plt.xlabel("Citric Acid")
plt.ylabel("Density")
plt.show()
# Out:
# /tmp/ipykernel_689/216100016.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['citric acid'], color = 'blue')

# %% [markdown]
# Same procedure we can follow fo rother numerical columns to get the mean, median(parameters of central tendency)

# %%
# Create a count plot of the "Quality" feature
plt.figure(figsize=(11, 6))

sns.countplot(data = data, x = 'quality')

plt.title("Count plot of Quality")
plt.xlabel("Quality")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Observation
# It is quite clear from the count plot that the 6 is the highest count of quality, whereas 9 is negligible

# %%
# Count the number of occurences of different categories of the "Quality" feature
data['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
# calculate the mode of the 'quality' featues
data['quality'].value_counts().index[0]
# Out:
# np.int64(6)

# %% [markdown]
# # Observations from Task 2
# We saw the distributions of the various features in the data set using appropriate plots.
#
# We calculated central tendency measures like mean, median and mode for the various features.
# The mean and the median for all the above features were similar, so we can choose the mean in these cases.
#
# The mode of the 'Quality' feature canbe chosen as a represntative value.

# %%
# Create a pandas series called 'rep_acid' that contains the details of the representatives quality

rep_acid = pd.Series(index = ['fixed acidity', 'volatile acidity', 'citric acid', 'quality'],
                     data = [data['fixed acidity'].mean(), data['volatile acidity'].mean(),
                             data['citric acid'].mean(), data['quality'].value_counts().index[0]])

# %%
# print the 'rep_acid' series
rep_acid
# Out:
# fixed acidity       6.854788
# volatile acidity    0.278241
# citric acid         0.334192
# quality             6.000000
# dtype: float64

# %% [markdown]
# # Observation from Task 3
#
# 1. The representative acid for the quality is as follows:
# 2. The mean value of the fixed acidity would be 6.854
# 3. The mean value of the volatile acidity would be 0.2782
# 4. The mean value of the citric acid would be 0.3341
# 5. The quality would be 6

# %% [markdown]
# # Final Conclusions
#
# * From the given data, we can use the simple visualizations to get a sense of how data are distributed.
# * We can use various measures of central tendency such as mean, median and mode to represent a group of observations.
# * The type of central tendency measures to use depends on the type and the distribution of the data.
